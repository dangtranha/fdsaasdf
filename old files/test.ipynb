# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import glob
import csv

# %%
# file1 = pd.read_csv('C:\\Users\\DUC_AN\\Documents\\GitHub\\BCI_Project\\datasets\\motor_imagery\\med_2021-08-26--18-45-49_174012250194033688.csv')
# file2 = pd.read_csv('C:\\Users\\DUC_AN\\Documents\\GitHub\\BCI_Project\\intermediate_datafiles\\motor_imagery\\step2_result\\med_2021-08-26--18-45-49_174012250194033688.csv')
file1 = pd.read_csv('C:\\Users\\DUC_AN\\Documents\\GitHub\\BCI_Project\\datasets\\drunk\\drunk10.csv')
file2 = pd.read_csv('C:\\Users\\DUC_AN\\Documents\\GitHub\\BCI_Project\\intermediate_datafiles\\drunk\\step1_result\\drunk10.csv')
file3 = pd.read_csv('C:\\Users\\DUC_AN\\Documents\\GitHub\\BCI_Project\\intermediate_datafiles\\drunk\\step2_result\\drunk10.csv')

value1 = file1.loc[:, 'Gamma_AF7']
value2 = file2.loc[:, 'Gamma_AF7']
value3 = file3.loc[:, 'Gamma_AF7']

cols = ['Delta_TP9','Delta_AF7','Delta_AF8','Delta_TP10',
    'Theta_TP9','Theta_AF7','Theta_AF8','Theta_TP10',
    'Alpha_TP9','Alpha_AF7','Alpha_AF8','Alpha_TP10',
    'Beta_TP9','Beta_AF7','Beta_AF8','Beta_TP10',
    'Gamma_TP9','Gamma_AF7','Gamma_AF8','Gamma_TP10']

# for c in cols:
#     value = file1[c]
#     plt.plot(value)

# %%
fig, axis = plt.subplots(3,1)
fig.set_size_inches(20,5)
axis[0].plot(value1)
axis[0].set_title('value1')
axis[1].plot(value2)
axis[1].set_title('value2')
axis[2].plot(value3)
axis[2].set_title('value3')
# Out:
# Text(0.5, 1.0, 'value3')

# %%
file = pd.read_csv('./Datasets/EEG_dataset.csv')
fig, axis = plt.subplots(2,2)
fig.set_size_inches(20,5)
axis[0][0].plot(file['Alpha_AF7'])
axis[0][0].set_title('Alpha_AF7')
axis[0][1].plot(file['Beta_AF7'])
axis[0][1].set_title('Beta_AF7')
axis[1][0].plot(file['Delta_AF7'])
axis[1][0].set_title('Delta_AF7')
axis[1][1].plot(file['Gamma_AF7'])
axis[1][1].set_title('Gamma_AF7')
# Out:
# Text(0.5, 1.0, 'Gamma_AF7')

# %%
fig, axis = plt.subplots(2,2)
fig.set_size_inches(20,5)
axis[0][0].plot(file['Alpha_AF8'])
axis[0][0].set_title('Alpha_AF8')
axis[0][1].plot(file['Beta_AF8'])
axis[0][1].set_title('Beta_AF8')
axis[1][0].plot(file['Delta_AF8'])
axis[1][0].set_title('Delta_AF8')
axis[1][1].plot(file['Gamma_AF8'])
axis[1][1].set_title('Gamma_AF8')
# Out:
# Text(0.5, 1.0, 'Gamma_AF8')

# %%
fig, axis = plt.subplots(2,2)
fig.set_size_inches(20,5)
axis[0][0].plot(file['Alpha_TP9'])
axis[0][0].set_title('Alpha_TP9')
axis[0][1].plot(file['Beta_TP9'])
axis[0][1].set_title('Beta_TP9')
axis[1][0].plot(file['Delta_TP9'])
axis[1][0].set_title('Delta_TP9')
axis[1][1].plot(file['Gamma_TP9'])
axis[1][1].set_title('Gamma_TP9')
# Out:
# Text(0.5, 1.0, 'Gamma_TP9')

# %%
fig, axis = plt.subplots(2,2)
fig.set_size_inches(20,5)
axis[0][0].plot(file['Alpha_TP10'])
axis[0][0].set_title('Alpha_TP10')
axis[0][1].plot(file['Beta_TP10'])
axis[0][1].set_title('Beta_TP10')
axis[1][0].plot(file['Delta_TP10'])
axis[1][0].set_title('Delta_TP10')
axis[1][1].plot(file['Gamma_TP10'])
axis[1][1].set_title('Gamma_TP10')
# Out:
# Text(0.5, 1.0, 'Gamma_TP10')

# %%
nguoita = pd.read_csv('C:\\Users\\DUC_AN\\Documents\\GitHub\\BCI_Project\\intermediate_datafiles\\motor_imagery\\step2_result\\med_2021-08-26--18-45-49_174012250194033688.csv')
minh = pd.read_csv('C:\\Users\\DUC_AN\\Documents\\GitHub\\BCI_Project\\intermediate_datafiles\\drunk\\step2_result\\drunk10.csv')

plt.plot(nguoita.loc[:1200, 'Gamma_AF7'])

# %%
plt.plot(minh.loc[:, 'Gamma_AF7'])

# %%
minh1 = pd.read_csv('C:\\Users\\DUC_AN\\Documents\\GitHub\\EEG-ICSSE\\nondrunk.csv')
fig, axis = plt.subplots(2,2)
fig.set_size_inches(20,5)
axis[0][0].plot(minh1['Alpha_AF7'])
axis[0][0].set_title('Alpha_AF7')
axis[0][1].plot(minh1['Beta_AF7'])
axis[0][1].set_title('Beta_AF7')
axis[1][0].plot(minh1['Delta_AF7'])
axis[1][0].set_title('Delta_AF7')
axis[1][1].plot(minh1['Gamma_AF7'])
axis[1][1].set_title('Gamma_AF7')
# Out:
# Text(0.5, 1.0, 'Gamma_AF7')

# %%
minh2 = pd.read_csv('C:\\Users\\DUC_AN\\Documents\\GitHub\\EEG-ICSSE\\drunk.csv')
fig, axis = plt.subplots(2,2)
fig.set_size_inches(20,5)
axis[0][0].plot(minh1['Alpha_AF7'])
axis[0][0].set_title('Alpha_AF7')
axis[0][1].plot(minh1['Beta_AF7'])
axis[0][1].set_title('Beta_AF7')
axis[1][0].plot(minh1['Delta_AF7'])
axis[1][0].set_title('Delta_AF7')
axis[1][1].plot(minh1['Gamma_AF7'])
axis[1][1].set_title('Gamma_AF7')
axis[0][0].plot(minh2['Alpha_AF7'])
axis[0][1].plot(minh2['Beta_AF7'])
axis[1][0].plot(minh2['Delta_AF7'])
axis[1][1].plot(minh2['Gamma_AF7'])
# Out:
# Text(0.5, 1.0, 'Gamma_AF7')

# %%
fig, axis = plt.subplots(2,2)
fig.set_size_inches(20,5)
axis[0][0].plot(minh1['Gamma_AF7'])
axis[0][0].plot(minh2['Gamma_AF7'])
axis[0][0].set_title('Alpha_AF7')
axis[0][1].plot(minh1['Beta_AF7'])
axis[0][1].set_title('Beta_AF7')
axis[0][1].plot(minh2['Beta_AF7'])
axis[1][0].plot(minh1['Delta_AF7'])
axis[1][0].set_title('Delta_AF7')
axis[1][0].plot(minh2['Delta_AF7'])
axis[1][1].plot(minh2['Gamma_AF7'])
axis[1][1].plot(minh1['Gamma_AF7'])
axis[1][1].set_title('Gamma_AF7')
# Out:
# Text(0.5, 1.0, 'Gamma_AF7')
